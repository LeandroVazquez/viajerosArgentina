# %% [markdown]
# #### Ejercicio de análisis de datos en Python.
# 1. Usé las librerías Numpy, Pandas y MatPlotLib.

# %% [markdown]
# ### Detalle del dataset
#
# Origen de datos: https://datos.gob.ar/dataset/turismo-encuesta-ocupacion-hotelera-parahotelera-eoh
#
# | Título de la columna | Tipo de dato | Descripción | Unidad de medida | Detalle de tipo especial |
# |----------------------|--------------|-------------|------------------|--------------------------|
# | indice_tiempo | Fecha ISO-8601 (date) | Indice de tiempo mensual | | Mensualmente |
# | origen_viajeros | Texto (string) | Tipo de residencia de los viajeros hospedados: residentes y no residentes de Argentina |
# | viajeros | Número decimal (number) | Viajeros hospedados en los establecimientos hoteleros y parahoteleros del país (persona que realiza una o más pernoctaciones seguidas en el mismo establecimiento y que abona por tal servicio). | viajeros |

# %%
##Realizo el llamado a las librerías que usaré
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##Cargo el archivo con los datos que analizaré
viajerosArgentina=pd.read_csv("viajeros-hospedados-residentes-y-no-residentes-por-destino.csv",delimiter=',')
viajerosArgentina
# Out:
#      indice_tiempo region_de_destino origen_viajeros  viajeros  \
# 0          2007-01      Buenos Aires      Residentes    401221
# 1          2007-01      Buenos Aires   No residentes     12889
# 2          2007-01              CABA      Residentes    139181
# 3          2007-01              CABA   No residentes    196750
# 4          2007-01           Córdoba      Residentes    255307
# ...            ...               ...             ...       ...
# 2387       2021-10           Litoral   No residentes      1373
# 2388       2021-10             Norte      Residentes    201969
# 2389       2021-10             Norte   No residentes      1796
# 2390       2021-10         Patagonia      Residentes    223597
# 2391       2021-10         Patagonia   No residentes      1758
#
#         observaciones
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 2387  Dato provisorio
# ...

# %%
##Separaré la fecha en dos, mes y año
viajerosArgentinaNueva=viajerosArgentina
viajerosArgentinaNueva["AñoMes"]=viajerosArgentinaNueva['indice_tiempo'].astype(str)
viajerosArgentinaNueva["año"]=viajerosArgentinaNueva["AñoMes"].str[0:4]
viajerosArgentinaNueva["mes"]=viajerosArgentinaNueva["AñoMes"].str[5:7]
viajerosArgentinaNueva
# Out:
#      indice_tiempo region_de_destino origen_viajeros  viajeros  \
# 0          2007-01      Buenos Aires      Residentes    401221
# 1          2007-01      Buenos Aires   No residentes     12889
# 2          2007-01              CABA      Residentes    139181
# 3          2007-01              CABA   No residentes    196750
# 4          2007-01           Córdoba      Residentes    255307
# ...            ...               ...             ...       ...
# 2387       2021-10           Litoral   No residentes      1373
# 2388       2021-10             Norte      Residentes    201969
# 2389       2021-10             Norte   No residentes      1796
# 2390       2021-10         Patagonia      Residentes    223597
# 2391       2021-10         Patagonia   No residentes      1758
#
#         observaciones   AñoMes   año mes
# 0                 NaN  2007-01  2007  01
# 1                 NaN  2007-01  2007  01
# 2                 NaN  2007-01  2007  01
# 3                 NaN  2007-01  2007  01
# ...

# %%
viajerosAnios=viajerosArgentinaNueva.groupby("año").sum("viajeros")
viajerosAnios.plot(kind="bar");
plt.title("Cantidad todal de viajeros por cada año")
plt.show()

# %%
viajerosProvincias=viajerosArgentinaNueva.groupby("region_de_destino")["viajeros"].sum()
viajerosProvincias.plot(kind="bar")
plt.title("Cantidad total de visitantes de cada región")
plt.show()

# %%
filtroBuenosAires=viajerosArgentinaNueva["region_de_destino"]=="Buenos Aires"
auxiliarBuenosAires=viajerosArgentinaNueva[filtroBuenosAires]
viajerosBuenosAires=auxiliarBuenosAires.groupby("año")["viajeros"].sum()

filtroCABA=viajerosArgentinaNueva["region_de_destino"]=="CABA"
auxiliarCABA=viajerosArgentinaNueva[filtroCABA]
viajerosCABA=auxiliarCABA.groupby("año")["viajeros"].sum()

filtroCuyo=viajerosArgentinaNueva["region_de_destino"]=="Cuyo"
auxiliarCuyo=viajerosArgentinaNueva[filtroCuyo]
viajerosCuyo=auxiliarCuyo.groupby("año")["viajeros"].sum()

filtroCordoba=viajerosArgentinaNueva["region_de_destino"]=="Córdoba"
auxiliarCordoba=viajerosArgentinaNueva[filtroCordoba]
viajerosCordoba=auxiliarCordoba.groupby("año")["viajeros"].sum()

filtroLitoral=viajerosArgentinaNueva["region_de_destino"]=="Litoral"
auxiliarLitoral=viajerosArgentinaNueva[filtroLitoral]
viajerosLitoral=auxiliarLitoral.groupby("año")["viajeros"].sum()

filtroNorte=viajerosArgentinaNueva["region_de_destino"]=="Norte"
auxiliarNorte=viajerosArgentinaNueva[filtroNorte]
viajerosNorte=auxiliarNorte.groupby("año")["viajeros"].sum()

filtroPatagonia=viajerosArgentinaNueva["region_de_destino"]=="Patagonia"
auxiliarPatagonia=viajerosArgentinaNueva[filtroPatagonia]
viajerosPatagonia=auxiliarPatagonia.groupby("año")["viajeros"].sum()

indice=["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]
tablaGeneral=pd.DataFrame({"Buenos Aires":viajerosBuenosAires,"CABA":viajerosCABA,"Cuyo":viajerosCuyo,"Córdoba":viajerosCordoba,"Litoral":viajerosLitoral,"Norte":viajerosNorte,"Patagonia":viajerosPatagonia},index=indice)
tablaGeneral.plot(kind="bar",figsize=(40,20))
plt.title("Cantidad total de viajeros por region destino por año")
plt.xlabel("Años")
plt.ylabel("Cantidad de viajeros")
plt.show()

# %%
viajerosArgentinaNueva.replace(to_replace="01",value="Enero",inplace=True)
viajerosArgentinaNueva.replace(to_replace="02",value="Febrero",inplace=True)
viajerosArgentinaNueva.replace(to_replace="03",value="Marzo",inplace=True)
viajerosArgentinaNueva.replace(to_replace="04",value="Abril",inplace=True)
viajerosArgentinaNueva.replace(to_replace="05",value="Mayo",inplace=True)
viajerosArgentinaNueva.replace(to_replace="06",value="Junio",inplace=True)
viajerosArgentinaNueva.replace(to_replace="07",value="Julio",inplace=True)
viajerosArgentinaNueva.replace(to_replace="08",value="Agosto",inplace=True)
viajerosArgentinaNueva.replace(to_replace="09",value="Septiembre",inplace=True)
viajerosArgentinaNueva.replace(to_replace="10",value="Octubre",inplace=True)
viajerosArgentinaNueva.replace(to_replace="11",value="Noviembre",inplace=True)
viajerosArgentinaNueva.replace(to_replace="12",value="Diciembre",inplace=True)
# Out:
#      indice_tiempo region_de_destino origen_viajeros  viajeros  \
# 0          2007-01      Buenos Aires      Residentes    401221
# 1          2007-01      Buenos Aires   No residentes     12889
# 2          2007-01              CABA      Residentes    139181
# 3          2007-01              CABA   No residentes    196750
# 4          2007-01           Córdoba      Residentes    255307
# ...            ...               ...             ...       ...
# 2387       2021-10           Litoral   No residentes      1373
# 2388       2021-10             Norte      Residentes    201969
# 2389       2021-10             Norte   No residentes      1796
# 2390       2021-10         Patagonia      Residentes    223597
# 2391       2021-10         Patagonia   No residentes      1758
#
#         observaciones   AñoMes   año      mes  Enero
# 0                 NaN  2007-01  2007    Enero  False
# 1                 NaN  2007-01  2007    Enero  False
# ...

# %%
filtroEnero=viajerosArgentinaNueva["mes"]=="Enero"
auxiliarEnero=viajerosArgentinaNueva[filtroEnero]
viajerosEnero=auxiliarEnero.groupby("año")["viajeros"].sum()

filtroFebrero=viajerosArgentinaNueva["mes"]=="Febrero"
auxiliarFebrero=viajerosArgentinaNueva[filtroFebrero]
viajerosFebrero=auxiliarFebrero.groupby("año")["viajeros"].sum()

filtroMarzo=viajerosArgentinaNueva["mes"]=="Marzo"
auxiliarMarzo=viajerosArgentinaNueva[filtroMarzo]
viajerosMarzo=auxiliarMarzo.groupby("año")["viajeros"].sum()

filtroAbril=viajerosArgentinaNueva["mes"]=="Abril"
auxiliarAbril=viajerosArgentinaNueva[filtroAbril]
viajerosAbril=auxiliarAbril.groupby("año")["viajeros"].sum()

filtroMayo=viajerosArgentinaNueva["mes"]=="Mayo"
auxiliarMayo=viajerosArgentinaNueva[filtroMayo]
viajerosMayo=auxiliarMayo.groupby("año")["viajeros"].sum()

filtroAbril=viajerosArgentinaNueva["mes"]=="Abril"
auxiliarAbril=viajerosArgentinaNueva[filtroAbril]
viajerosAbril=auxiliarAbril.groupby("año")["viajeros"].sum()

filtroJunio=viajerosArgentinaNueva["mes"]=="Junio"
auxiliarJunio=viajerosArgentinaNueva[filtroJunio]
viajerosJunio=auxiliarJunio.groupby("año")["viajeros"].sum()

filtroJulio=viajerosArgentinaNueva["mes"]=="Julio"
auxiliarJulio=viajerosArgentinaNueva[filtroJulio]
viajerosJulio=auxiliarJulio.groupby("año")["viajeros"].sum()

filtroAgosto=viajerosArgentinaNueva["mes"]=="Agosto"
auxiliarAgosto=viajerosArgentinaNueva[filtroAgosto]
viajerosAgosto=auxiliarAgosto.groupby("año")["viajeros"].sum()

filtroSeptiembre=viajerosArgentinaNueva["mes"]=="Septiembre"
auxiliarSeptiembre=viajerosArgentinaNueva[filtroSeptiembre]
viajerosSeptiembre=auxiliarSeptiembre.groupby("año")["viajeros"].sum()

filtroOctubre=viajerosArgentinaNueva["mes"]=="Octubre"
auxiliarOctubre=viajerosArgentinaNueva[filtroOctubre]
viajerosOctubre=auxiliarOctubre.groupby("año")["viajeros"].sum()

filtroNoviembre=viajerosArgentinaNueva["mes"]=="Noviembre"
auxiliarNoviembre=viajerosArgentinaNueva[filtroNoviembre]
viajerosNoviembre=auxiliarNoviembre.groupby("año")["viajeros"].sum()

filtroDiciembre=viajerosArgentinaNueva["mes"]=="Diciembre"
auxiliarDiciembre=viajerosArgentinaNueva[filtroDiciembre]
viajerosDiciembre=auxiliarDiciembre.groupby("año")["viajeros"].sum()


indice=["2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]
tablaGeneralMeses=pd.DataFrame({"Enero":viajerosEnero,"Febrero":viajerosFebrero,"Marzo":viajerosMarzo,"Abril":viajerosAbril,"Mayo":viajerosMayo,"Junio":viajerosJunio,"Julio":viajerosJulio,"Agosto":viajerosAgosto,"Septiemnbre":viajerosSeptiembre,"Octubre":viajerosOctubre,"Noviembre":viajerosNoviembre,"Diciembre":viajerosDiciembre},index=indice)
tablaGeneralMeses.plot(kind="bar",figsize=(40,20))
##plt.title("Cantidad total de viajeros por region destino por año")
##plt.xlabel("Años")
##plt.ylabel("Cantidad de viajeros")
plt.show()
